# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("D:\\Ultimate Programming\\Data Bases\\Expense3.xlsx")
df = pd.DataFrame(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           29 non-null     datetime64[ns]
#  1   Category       29 non-null     object
#  2   Sub-Category   29 non-null     object
#  3   Amount         29 non-null     int64
#  4   Payment Mode   25 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 1.3+ KB

# %%
print(df["Payment Mode"].isnull().sum())
# Out:
# 4

# %%
df["Payment Mode"] = df["Payment Mode"].replace(np.nan, "Hello")

# %%
plt.bar(df["Payment Mode"], df["Amount"])
plt.xlabel("Payment Mode")
plt.show()

# %%
plt.pie(df["Amount"])
plt.show()

# %%
gp = df.groupby("Category").agg({"Payment Mode": "count"})

# %%
df = pd.read_excel("D:\\Ultimate Programming\\Data Bases\\Banking Data.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client ID                 3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Sex                       3000 non-null   object
#  4   Location ID               3000 non-null   int64
#  5   Joined Bank               3000 non-null   datetime64[ns]
#  6   Banking Contact           3000 non-null   object
#  7   Nationality               3000 non-null   object
#  8   Occupation                3000 non-null   object
#  9   Investment Advisor        3000 non-null   object
#  10  Fee Structure             3000 non-null   object
#  11  Loyalty Classification    3000 non-null   object
#  12  Banking Relationship      3000 non-null   object
# ...

# %%
df.head(10)
# Out:
#   Client ID               Name  Age     Sex  Location ID Joined Bank  \
# 0  PKR81288      Raymond Mills   24    Male        34324  2019-05-06
# 1  PKR65833      Julia Spencer   23    Male        42205  2001-12-10
# 2  PKR47499     Stephen Murray   27  Female         7314  2010-01-25
# 3  PKR72498     Virginia Garza   40    Male        34594  1993-03-28
# 4  PKR60181    Melissa Sanders   46  Female        41269  2012-07-20
# 5  PKR78532      Samuel Hudson   23    Male        13204  2019-02-07
# 6  PKR95683  Timothy Alexander   46  Female        42910  2002-06-02
# 7  PKR40785        Carl Martin   78  Female         6127  2000-11-03
# 8  PKR13570         Philip Day   67  Female        32656  2015-04-07
# 9  PKR53299         Jason Sims   51    Male        28340  1995-11-20
#
#     Banking Contact Nationality                 Occupation Investment Advisor  \
# 0    Anthony Torres    American       Safety Technician IV        Victor Dean
# ...

# %%
gp = df.groupby("Nationality")["Credit Card Balance"].min()
gp
# Out:
# Nationality
# African       37.5224
# American      27.8080
# Asian          4.2484
# Australian    10.6764
# European       1.1748
# Name: Credit Card Balance, dtype: float64

# %%
plt.pie(gp.values, labels = gp.index, autopct = "%.2f")
plt.show()

# %%
plt.bar(df["Sex"], df["Nationality"])
plt.show()

# %%
gp = df.groupby(["Nationality"]).agg({"Client ID" : "count"})
gp
# Out:
#              Client ID
# Nationality
# African            176
# American           507
# Asian              754
# Australian         254
# European          1309
